# %%
import os
TRAIN_ABLE_FALSE=True
if TRAIN_ABLE_FALSE:
    os.environ['CUDA_VISIBLE_DEVICES'] = "1"
import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime

TRAIN_OFFLINE = True


pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})
if TRAIN_OFFLINE:
    train = pd.read_csv('../../nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})
else:
    train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %%
train.head()
# Out:
#        GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0  2017090700  20170907000118  away  73.91  34.84  1.69  1.13  0.40
# 1  2017090700  20170907000118  away  74.67  32.64  0.42  1.35  0.01
# 2  2017090700  20170907000118  away  74.00  33.20  1.22  0.59  0.31
# 3  2017090700  20170907000118  away  71.46  27.70  0.42  0.54  0.02
# 4  2017090700  20170907000118  away  69.32  35.42  1.82  2.43  0.16
#
#    Orientation     Dir    NflId      DisplayName  JerseyNumber  Season  \
# 0        81.99  177.18   496723       Eric Berry            29    2017
# 1        27.61  198.70  2495116     Allen Bailey            97    2017
# 2         3.01  202.73  2495493   Justin Houston            50    2017
# 3       359.77  105.64  2506353  Derrick Johnson            56    2017
# 4        12.63  164.31  2530794       Ron Parker            38    2017
#
#    YardLine  Quarter GameClock PossessionTeam  Down  Distance FieldPosition  \
# 0        35        1  14:14:00             NE     3         2            NE
# 1        35        1  14:14:00             NE     3         2            NE
# 2        35        1  14:14:00             NE     3         2            NE
# 3        35        1  14:14:00             NE     3         2            NE
# 4        35        1  14:14:00             NE     3         2            NE
#
#    HomeScoreBeforePlay  VisitorScoreBeforePlay  NflIdRusher OffenseFormation  \
# 0                    0                       0      2543773          SHOTGUN
# 1                    0                       0      2543773          SHOTGUN
# 2                    0                       0      2543773          SHOTGUN
# 3                    0                       0      2543773          SHOTGUN
# 4                    0                       0      2543773          SHOTGUN
#
#    OffensePersonnel  DefendersInTheBox  DefensePersonnel PlayDirection  \
# 0  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 1  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 2  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 3  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 4  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
#
#                 TimeHandoff                  TimeSnap  Yards PlayerHeight  \
# 0  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-0
# 1  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 2  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 3  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 4  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-0
#
#    PlayerWeight PlayerBirthDate PlayerCollegeName Position HomeTeamAbbr  \
# 0           212      12/29/1988         Tennessee       SS           NE
# 1           288      03/25/1989             Miami       DE           NE
# 2           270      01/21/1989           Georgia       DE           NE
# 3           245      11/22/1982             Texas      ILB           NE
# 4           206      08/17/1987          Newberry       FS           NE
#
#   VisitorTeamAbbr  Week           Stadium        Location StadiumType  \
# 0              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 1              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 2              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 3              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 4              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
#
#          Turf     GameWeather  Temperature  Humidity WindSpeed WindDirection
# 0  Field Turf  Clear and warm         63.0      77.0         8            SW
# 1  Field Turf  Clear and warm         63.0      77.0         8            SW
# 2  Field Turf  Clear and warm         63.0      77.0         8            SW
# 3  Field Turf  Clear and warm         63.0      77.0         8            SW
# 4  Field Turf  Clear and warm         63.0      77.0         8            SW

# %%
def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
def preprocess(train):
    ## GameClock
    train['GameClock_sec'] = train['GameClock'].apply(strtoseconds)
    train["GameClock_minute"] = train["GameClock"].apply(lambda x : x.split(":")[0]).astype("object")

    ## Height
    train['PlayerHeight_dense'] = train['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))

    ## Time
    train['TimeHandoff'] = train['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeSnap'] = train['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

    train['TimeDelta'] = train.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
    train['PlayerBirthDate'] = train['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

    ## Age
    seconds_in_year = 60*60*24*365.25
    train['PlayerAge'] = train.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
    train["PlayerAge_ob"] = train['PlayerAge'].astype(np.int).astype("object")

    ## WindSpeed
    train['WindSpeed_ob'] = train['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
    train['WindSpeed_dense'] = train['WindSpeed_ob'].apply(strtofloat)

    ## Weather
    train['GameWeather_process'] = train['GameWeather'].str.lower()
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
    train['GameWeather_dense'] = train['GameWeather_process'].apply(map_weather)

    ## Rusher
    train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
    train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
    temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    train = train.merge(temp, on = "PlayId")
    train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

    ## dense -> categorical
    train["Quarter_ob"] = train["Quarter"].astype("object")
    train["Down_ob"] = train["Down"].astype("object")
    train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
    train["YardLine_ob"] = train["YardLine"].astype("object")
    # train["DefendersInTheBox_ob"] = train["DefendersInTheBox"].astype("object")
    # train["Week_ob"] = train["Week"].astype("object")
    # train["TimeDelta_ob"] = train["TimeDelta"].astype("object")


    ## Orientation and Dir
    train["Orientation_ob"] = train["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
    train["Dir_ob"] = train["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

    train["Orientation_sin"] = train["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Orientation_cos"] = train["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
    train["Dir_sin"] = train["Dir"].apply(lambda x : 90)
    train["Dir_cos"] = train["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))

    ## diff Score
    train["diffScoreBeforePlay"] = train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]
    train["diffScoreBeforePlay_binary_ob"] = (train["HomeScoreBeforePlay"] > train["VisitorScoreBeforePlay"]).astype("object")

    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)

    ## OffensePersonnel
    temp = train["OffensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(OffensePersonnelSplit(x)))
    temp.columns = ["Offense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## DefensePersonnel
    temp = train["DefensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(DefensePersonnelSplit(x)))
    temp.columns = ["Defense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## sort
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'Team', 'IsRusher']).reset_index(drop = True)
    train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)
    return train

# %%
train.loc[train.VisitorTeamAbbr == "ARI", 'VisitorTeamAbbr'] = "ARZ"
train.loc[train.HomeTeamAbbr == "ARI", 'HomeTeamAbbr'] = "ARZ"

train.loc[train.VisitorTeamAbbr == "BAL", 'VisitorTeamAbbr'] = "BLT"
train.loc[train.HomeTeamAbbr == "BAL", 'HomeTeamAbbr'] = "BLT"

train.loc[train.VisitorTeamAbbr == "CLE", 'VisitorTeamAbbr'] = "CLV"
train.loc[train.HomeTeamAbbr == "CLE", 'HomeTeamAbbr'] = "CLV"

train.loc[train.VisitorTeamAbbr == "HOU", 'VisitorTeamAbbr'] = "HST"
train.loc[train.HomeTeamAbbr == "HOU", 'HomeTeamAbbr'] = "HST"

# %%
train
# Out:
#             GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0       2017090700  20170907000118  away  73.91  34.84  1.69  1.13  0.40
# 1       2017090700  20170907000118  away  74.67  32.64  0.42  1.35  0.01
# 2       2017090700  20170907000118  away  74.00  33.20  1.22  0.59  0.31
# 3       2017090700  20170907000118  away  71.46  27.70  0.42  0.54  0.02
# 4       2017090700  20170907000118  away  69.32  35.42  1.82  2.43  0.16
# ...            ...             ...   ...    ...    ...   ...   ...   ...
# 509757  2018123015  20181230154157  home  86.77  24.20  2.14  2.12  0.22
# 509758  2018123015  20181230154157  home  86.76  27.18  1.16  0.66  0.11
# 509759  2018123015  20181230154157  home  87.26  27.05  2.59  1.18  0.26
# 509760  2018123015  20181230154157  home  84.57  24.37  4.36  1.79  0.47
# 509761  2018123015  20181230154157  home  80.80  26.35  4.87  4.10  0.45
#
#         Orientation     Dir    NflId      DisplayName  JerseyNumber  Season  \
# 0             81.99  177.18   496723       Eric Berry            29    2017
# 1             27.61  198.70  2495116     Allen Bailey            97    2017
# 2              3.01  202.73  2495493   Justin Houston            50    2017
# 3            359.77  105.64  2506353  Derrick Johnson            56    2017
# 4             12.63  164.31  2530794       Ron Parker            38    2017
# ...             ...     ...      ...              ...           ...     ...
# 509757        44.55   15.31  2555289     Nick Vannett            81    2018
# 509758        53.63   42.80  2555395    Germain Ifedi            65    2018
# 509759         3.96   21.12  2556524      George Fant            74    2018
# 509760       148.08  183.34  2557891      Ethan Pocic            77    2018
# 509761       135.44  118.24  2558865     Chris Carson            32    2018
#
#         YardLine  Quarter GameClock PossessionTeam  Down  Distance  \
# 0             35        1  14:14:00             NE     3         2
# 1             35        1  14:14:00             NE     3         2
# 2             35        1  14:14:00             NE     3         2
# 3             35        1  14:14:00             NE     3         2
# 4             35        1  14:14:00             NE     3         2
# ...          ...      ...       ...            ...   ...       ...
# 509757        23        4  00:16:00            SEA     2         8
# 509758        23        4  00:16:00            SEA     2         8
# 509759        23        4  00:16:00            SEA     2         8
# 509760        23        4  00:16:00            SEA     2         8
# 509761        23        4  00:16:00            SEA     2         8
#
#        FieldPosition  HomeScoreBeforePlay  VisitorScoreBeforePlay  \
# 0                 NE                    0                       0
# 1                 NE                    0                       0
# 2                 NE                    0                       0
# 3                 NE                    0                       0
# 4                 NE                    0                       0
# ...              ...                  ...                     ...
# 509757           ARZ                   24                      24
# 509758           ARZ                   24                      24
# 509759           ARZ                   24                      24
# 509760           ARZ                   24                      24
# 509761           ARZ                   24                      24
#
#         NflIdRusher OffenseFormation        OffensePersonnel  \
# 0           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 1           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 2           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 3           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 4           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# ...             ...              ...                     ...
# 509757      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509758      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509759      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509760      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509761      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
#
#         DefendersInTheBox  DefensePersonnel PlayDirection  \
# 0                     6.0  2 DL, 3 LB, 6 DB          left
# 1                     6.0  2 DL, 3 LB, 6 DB          left
# 2                     6.0  2 DL, 3 LB, 6 DB          left
# 3                     6.0  2 DL, 3 LB, 6 DB          left
# 4                     6.0  2 DL, 3 LB, 6 DB          left
# ...                   ...               ...           ...
# 509757                9.0  4 DL, 3 LB, 4 DB         right
# 509758                9.0  4 DL, 3 LB, 4 DB         right
# 509759                9.0  4 DL, 3 LB, 4 DB         right
# 509760                9.0  4 DL, 3 LB, 4 DB         right
# 509761                9.0  4 DL, 3 LB, 4 DB         right
#
#                      TimeHandoff                  TimeSnap  Yards  \
# 0       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 1       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 2       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 3       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 4       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# ...                          ...                       ...    ...
# 509757  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509758  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509759  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509760  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509761  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
#
#        PlayerHeight  PlayerWeight PlayerBirthDate PlayerCollegeName Position  \
# 0               6-0           212      12/29/1988         Tennessee       SS
# 1               6-3           288      03/25/1989             Miami       DE
# 2               6-3           270      01/21/1989           Georgia       DE
# 3               6-3           245      11/22/1982             Texas      ILB
# 4               6-0           206      08/17/1987          Newberry       FS
# ...             ...           ...             ...               ...      ...
# 509757          6-6           261      03/06/1993        Ohio State       TE
# 509758          6-5           325      06/02/1994         Texas A&M        G
# 509759          6-5           322      07/19/1992  Western Kentucky       OT
# 509760          6-6           320      08/05/1995   Louisiana State        C
# 509761         5-11           222      09/16/1994    Oklahoma State       RB
#
#        HomeTeamAbbr VisitorTeamAbbr  Week            Stadium        Location  \
# 0                NE              KC     1   Gillette Stadium  Foxborough, MA
# 1                NE              KC     1   Gillette Stadium  Foxborough, MA
# 2                NE              KC     1   Gillette Stadium  Foxborough, MA
# 3                NE              KC     1   Gillette Stadium  Foxborough, MA
# 4                NE              KC     1   Gillette Stadium  Foxborough, MA
# ...             ...             ...   ...                ...             ...
# 509757          SEA             ARZ    17  CenturyLink Field     Seattle, WA
# 509758          SEA             ARZ    17  CenturyLink Field     Seattle, WA
# 509759          SEA             ARZ    17  CenturyLink Field     Seattle, WA
# 509760          SEA             ARZ    17  CenturyLink Field     Seattle, WA
# 509761          SEA             ARZ    17  CenturyLink Field     Seattle, WA
#
#        StadiumType        Turf     GameWeather  Temperature  Humidity  \
# 0          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 1          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 2          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 3          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 4          Outdoor  Field Turf  Clear and warm         63.0      77.0
# ...            ...         ...             ...          ...       ...
# 509757     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509758     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509759     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509760     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509761     Outdoor   FieldTurf          Cloudy         45.0      76.0
#
#        WindSpeed WindDirection
# 0              8            SW
# 1              8            SW
# 2              8            SW
# 3              8            SW
# 4              8            SW
# ...          ...           ...
# 509757         5            SE
# 509758         5            SE
# 509759         5            SE
# 509760         5            SE
# 509761         5            SE
#
# [509762 rows x 49 columns]

# %% [markdown]
# ### Functions for anchoring offense moving left from {0,0}

# %%
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append('GameWeather_dense')
#         ## Rusher
#         train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
#         train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
#         temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
#         train = train.merge(temp, on = "PlayId")
#         train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

        ## dense -> categorical
#         train["Quarter_ob"] = train["Quarter"].astype("object")
#         train["Down_ob"] = train["Down"].astype("object")
#         train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
#         train["YardLine_ob"] = train["YardLine"].astype("object")
        # train["DefendersInTheBox_ob"] = train["DefendersInTheBox"].astype("object")
        # train["Week_ob"] = train["Week"].astype("object")
        # train["TimeDelta_ob"] = train["TimeDelta"].astype("object")


        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
        
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()
#         static_features['DefendersInTheBox'] = static_features['DefendersInTheBox'].fillna(np.mean(static_features['DefendersInTheBox']))
        static_features.fillna(-999,inplace=True)
#         for i in add_new_feas:
#             static_features[i] = static_features[i].fillna(np.mean(static_features[i]))
            

        return static_features


    def combine_features(relative_to_back, defense, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, def_feats, static_feats, deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 2min 46s, sys: 4.17 s, total: 2min 50s
# Wall time: 2min 53s

# %%
train
# Out:
#             GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0       2017090700  20170907000118  away  46.09  34.84  1.69  1.13  0.40
# 1       2017090700  20170907000118  away  45.33  32.64  0.42  1.35  0.01
# 2       2017090700  20170907000118  away  46.00  33.20  1.22  0.59  0.31
# 3       2017090700  20170907000118  away  48.54  27.70  0.42  0.54  0.02
# 4       2017090700  20170907000118  away  50.68  35.42  1.82  2.43  0.16
# ...            ...             ...   ...    ...    ...   ...   ...   ...
# 509757  2018123015  20181230154157  home  86.77  24.20  2.14  2.12  0.22
# 509758  2018123015  20181230154157  home  86.76  27.18  1.16  0.66  0.11
# 509759  2018123015  20181230154157  home  87.26  27.05  2.59  1.18  0.26
# 509760  2018123015  20181230154157  home  84.57  24.37  4.36  1.79  0.47
# 509761  2018123015  20181230154157  home  80.80  26.35  4.87  4.10  0.45
#
#         Orientation     Dir    NflId      DisplayName  JerseyNumber  Season  \
# 0            278.01  182.82   496723       Eric Berry            29    2017
# 1            332.39  161.30  2495116     Allen Bailey            97    2017
# 2            356.99  157.27  2495493   Justin Houston            50    2017
# 3              0.23  254.36  2506353  Derrick Johnson            56    2017
# 4            347.37  195.69  2530794       Ron Parker            38    2017
# ...             ...     ...      ...              ...           ...     ...
# 509757        44.55   15.31  2555289     Nick Vannett            81    2018
# 509758        53.63   42.80  2555395    Germain Ifedi            65    2018
# 509759         3.96   21.12  2556524      George Fant            74    2018
# 509760       148.08  183.34  2557891      Ethan Pocic            77    2018
# 509761       135.44  118.24  2558865     Chris Carson            32    2018
#
#         YardLine  Quarter GameClock PossessionTeam  Down  Distance  \
# 0             35        1  14:14:00             NE     3         2
# 1             35        1  14:14:00             NE     3         2
# 2             35        1  14:14:00             NE     3         2
# 3             35        1  14:14:00             NE     3         2
# 4             35        1  14:14:00             NE     3         2
# ...          ...      ...       ...            ...   ...       ...
# 509757        23        4  00:16:00            SEA     2         8
# 509758        23        4  00:16:00            SEA     2         8
# 509759        23        4  00:16:00            SEA     2         8
# 509760        23        4  00:16:00            SEA     2         8
# 509761        23        4  00:16:00            SEA     2         8
#
#        FieldPosition  HomeScoreBeforePlay  VisitorScoreBeforePlay  \
# 0                 NE                    0                       0
# 1                 NE                    0                       0
# 2                 NE                    0                       0
# 3                 NE                    0                       0
# 4                 NE                    0                       0
# ...              ...                  ...                     ...
# 509757           ARZ                   24                      24
# 509758           ARZ                   24                      24
# 509759           ARZ                   24                      24
# 509760           ARZ                   24                      24
# 509761           ARZ                   24                      24
#
#         NflIdRusher OffenseFormation        OffensePersonnel  \
# 0           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 1           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 2           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 3           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 4           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# ...             ...              ...                     ...
# 509757      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509758      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509759      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509760      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509761      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
#
#         DefendersInTheBox  DefensePersonnel PlayDirection  \
# 0                     6.0  2 DL, 3 LB, 6 DB          left
# 1                     6.0  2 DL, 3 LB, 6 DB          left
# 2                     6.0  2 DL, 3 LB, 6 DB          left
# 3                     6.0  2 DL, 3 LB, 6 DB          left
# 4                     6.0  2 DL, 3 LB, 6 DB          left
# ...                   ...               ...           ...
# 509757                9.0  4 DL, 3 LB, 4 DB         right
# 509758                9.0  4 DL, 3 LB, 4 DB         right
# 509759                9.0  4 DL, 3 LB, 4 DB         right
# 509760                9.0  4 DL, 3 LB, 4 DB         right
# 509761                9.0  4 DL, 3 LB, 4 DB         right
#
#                      TimeHandoff                  TimeSnap  Yards  \
# 0       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 1       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 2       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 3       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 4       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# ...                          ...                       ...    ...
# 509757  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509758  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509759  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509760  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509761  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
#
#        PlayerHeight  PlayerWeight PlayerBirthDate PlayerCollegeName Position  \
# 0               6-0           212      12/29/1988         Tennessee       SS
# 1               6-3           288      03/25/1989             Miami       DE
# 2               6-3           270      01/21/1989           Georgia       DE
# 3               6-3           245      11/22/1982             Texas      ILB
# 4               6-0           206      08/17/1987          Newberry       FS
# ...             ...           ...             ...               ...      ...
# 509757          6-6           261      03/06/1993        Ohio State       TE
# 509758          6-5           325      06/02/1994         Texas A&M        G
# 509759          6-5           322      07/19/1992  Western Kentucky       OT
# 509760          6-6           320      08/05/1995   Louisiana State        C
# 509761         5-11           222      09/16/1994    Oklahoma State       RB
#
#        HomeTeamAbbr VisitorTeamAbbr  Week            Stadium        Location  \
# 0                NE              KC     1   Gillette Stadium  Foxborough, MA
# 1                NE              KC     1   Gillette Stadium  Foxborough, MA
# 2                NE              KC     1   Gillette Stadium  Foxborough, MA
# 3                NE              KC     1   Gillette Stadium  Foxborough, MA
# 4                NE              KC     1   Gillette Stadium  Foxborough, MA
# ...             ...             ...   ...                ...             ...
# 509757          SEA             ARZ    17  CenturyLink Field     Seattle, WA
# 509758          SEA             ARZ    17  CenturyLink Field     Seattle, WA
# 509759          SEA             ARZ    17  CenturyLink Field     Seattle, WA
# 509760          SEA             ARZ    17  CenturyLink Field     Seattle, WA
# 509761          SEA             ARZ    17  CenturyLink Field     Seattle, WA
#
#        StadiumType        Turf     GameWeather  Temperature  Humidity  \
# 0          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 1          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 2          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 3          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 4          Outdoor  Field Turf  Clear and warm         63.0      77.0
# ...            ...         ...             ...          ...       ...
# 509757     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509758     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509759     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509760     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509761     Outdoor   FieldTurf          Cloudy         45.0      76.0
#
#        WindSpeed WindDirection
# 0              8            SW
# 1              8            SW
# 2              8            SW
# 3              8            SW
# 4              8            SW
# ...          ...           ...
# 509757         5            SE
# 509758         5            SE
# 509759         5            SE
# 509760         5            SE
# 509761         5            SE
#
# [509762 rows x 49 columns]

# %%
train_basetable
# Out:
#            GameId          PlayId  back_from_scrimmage  \
# 0      2017090700  20170907000118                 3.75
# 1      2017090700  20170907000139                 4.07
# 2      2017090700  20170907000189                 3.66
# 3      2017090700  20170907000345                 3.53
# 4      2017090700  20170907000395                 5.01
# ...           ...             ...                  ...
# 23166  2018123015  20181230153910                 4.57
# 23167  2018123015  20181230154035                 4.00
# 23168  2018123015  20181230154082                 4.07
# 23169  2018123015  20181230154135                 3.81
# 23170  2018123015  20181230154157                 6.20
#
#        back_oriented_down_field  back_moving_down_field  min_dist   max_dist  \
# 0                             1                       0  1.449724  22.415872
# 1                             0                       0  0.792023  23.025872
# 2                             1                       0  1.646390  20.726285
# 3                             0                       0  0.918096   9.791231
# 4                             0                       0  0.502892  21.214806
# ...                         ...                     ...       ...        ...
# 23166                         0                       0  0.575847  19.341419
# 23167                         0                       0  1.151217  25.500196
# 23168                         0                       0  0.776209  19.454503
# 23169                         0                       0  0.584637  19.113474
# 23170                         0                       0  1.204159  18.918100
#
#        mean_dist  std_dist  def_min_dist  def_max_dist  def_mean_dist  \
# 0       8.046559  4.873845      4.593310     22.415872       9.752491
# 1       8.614623  5.598683      4.287773     23.025872      10.297028
# 2       8.482583  4.642121      4.221670     20.726285       9.903689
# 3       5.549379  1.983128      4.528002      9.791231       6.309354
# 4       9.168819  5.611232      4.288088     21.214806      11.056456
# ...          ...       ...           ...           ...            ...
# 23166   6.736412  4.514974      2.942329     19.341419       8.243270
# 23167   9.827962  7.474030      2.808932     25.500196      11.779213
# 23168   8.272970  5.548527      3.595998     19.454503       8.825731
# 23169   8.202171  5.833721      4.090880     19.113474       9.062557
# 23170   7.826834  4.535856      5.328461     18.918100       9.137466
#
#        def_std_dist  PlayerHeight_dense  PlayerAge  WindSpeed_dense  \
# 0          5.327299                  70  25.596251              8.0
# 1          5.833217                  70  25.596252              8.0
# 2          5.073290                  70  25.596253              8.0
# 3          1.834174                  71  26.852933              8.0
# 4          5.900009                  71  22.091819              8.0
# ...             ...                 ...        ...              ...
# 23166      5.075063                  73  27.041779              5.0
# 23167      7.739310                  69  25.861781              5.0
# 23168      5.317643                  69  25.861783              5.0
# 23169      5.568974                  71  24.290258              5.0
# 23170      4.853538                  71  24.290259              5.0
#
#        GameWeather_dense   Dir_sin   Dir_cos  diffScoreBeforePlay       X  \
# 0                    1.0  0.911690 -0.410878                    0   41.25
# 1                    1.0  0.740805  0.671721                    0   48.93
# 2                    1.0  0.668612 -0.743612                    0   71.34
# 3                    1.0  0.995496  0.094803                    0  104.47
# 4                    1.0  0.375901 -0.926660                    7   29.99
# ...                  ...       ...       ...                  ...     ...
# 23166               -1.0  0.938312  0.345790                    3   70.43
# 23167               -1.0  0.485115 -0.874450                    0   31.00
# 23168               -1.0  0.659346  0.751840                    0   39.93
# 23169               -1.0  0.659215  0.751955                    0   81.19
# 23170               -1.0  0.880973 -0.473166                    0   80.80
#
#            Y     S     A   Dis  Orientation     Dir  YardLine  Quarter  Down  \
# 0      30.53  3.63  3.35  0.38       198.02  114.26      45.0        1     3
# 1      27.16  3.06  2.41  0.34       149.30   47.80      53.0        1     1
# 2      19.11  5.77  2.42  0.60       219.18  138.04      75.0        1     1
# 3      25.36  4.45  3.20  0.46       173.78   84.56     108.0        1     2
# 4      27.12  3.90  2.53  0.44        34.27  157.92      35.0        1     1
# ...      ...   ...   ...   ...          ...     ...       ...      ...   ...
# 23166  32.27  3.99  3.38  0.39        72.56   69.77      75.0        4     1
# 23167  30.99  4.18  2.95  0.40       122.97  150.98      35.0        4     1
# 23168  29.20  4.67  3.68  0.45        63.11   41.25      44.0        4     3
# 23169  23.75  4.23  2.43  0.41        66.34   41.24      85.0        4     1
# 23170  26.35  4.87  4.10  0.45       135.44  118.24      87.0        4     2
#
#        Distance  DefendersInTheBox  Yards
# 0             2                6.0      8
# 1            10                6.0      3
# 2            10                7.0      5
# 3             2                9.0      2
# 4            10                7.0      7
# ...         ...                ...    ...
# 23166        10                8.0      1
# 23167        10                6.0      4
# 23168         1                7.0      4
# 23169        10                7.0      2
# 23170         8                9.0     11
#
# [23171 rows x 33 columns]

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=12345)

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (19695, 30) (3476, 30)
# (19695, 199) (3476, 199)

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import codecs

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.metrics import f1_score




class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
from keras import regularizers
from keras import optimizers

def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
from sklearn.model_selection import train_test_split, KFold
import time

losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 2s 109us/step - loss: 5.5829
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08281, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 5.1088
#
# Epoch 00002: CRPS_score_val improved from 0.08281 to 0.07773, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 2s 88us/step - loss: 4.6940
#
# Epoch 00003: CRPS_score_val improved from 0.07773 to 0.06380, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 1s 77us/step - loss: 4.3014
#
# Epoch 00004: CRPS_score_val improved from 0.06380 to 0.04444, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 2s 85us/step - loss: 3.9384
#
# Epoch 00005: CRPS_score_val improved from 0.04444 to 0.02835, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 3.6015
#
# Epoch 00006: CRPS_score_val improved from 0.02835 to 0.01988, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 1s 76us/step - loss: 3.3345
#
# Epoch 00007: CRPS_score_val improved from 0.01988 to 0.01614, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 1s 75us/step - loss: 3.1448
#
# Epoch 00008: CRPS_score_val improved from 0.01614 to 0.01450, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 2s 86us/step - loss: 3.0240
#
# Epoch 00009: CRPS_score_val improved from 0.01450 to 0.01376, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.9493
#
# Epoch 00010: CRPS_score_val improved from 0.01376 to 0.01355, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 2s 84us/step - loss: 2.8990
#
# Epoch 00011: CRPS_score_val improved from 0.01355 to 0.01341, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.8715
#
# Epoch 00012: CRPS_score_val improved from 0.01341 to 0.01336, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.8564
#
# Epoch 00013: CRPS_score_val improved from 0.01336 to 0.01332, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.8282
#
# Epoch 00014: CRPS_score_val improved from 0.01332 to 0.01326, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 2s 109us/step - loss: 2.8098
#
# Epoch 00015: CRPS_score_val improved from 0.01326 to 0.01321, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 2s 83us/step - loss: 2.7978
#
# Epoch 00016: CRPS_score_val improved from 0.01321 to 0.01319, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.7885
#
# Epoch 00017: CRPS_score_val improved from 0.01319 to 0.01313, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 2s 93us/step - loss: 2.7745
#
# Epoch 00018: CRPS_score_val improved from 0.01313 to 0.01310, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 2s 85us/step - loss: 2.7650
#
# Epoch 00019: CRPS_score_val improved from 0.01310 to 0.01307, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 2s 109us/step - loss: 2.7578
#
# Epoch 00020: CRPS_score_val improved from 0.01307 to 0.01306, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 2s 124us/step - loss: 2.7515
#
# Epoch 00021: CRPS_score_val improved from 0.01306 to 0.01305, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 2s 118us/step - loss: 2.7479
#
# Epoch 00022: CRPS_score_val improved from 0.01305 to 0.01302, saving model to best_model.h5
# Epoch 23/100
# 18536/18536 [==============================] - 2s 115us/step - loss: 2.7374
#
# Epoch 00023: CRPS_score_val improved from 0.01302 to 0.01299, saving model to best_model.h5
# Epoch 24/100
# 18536/18536 [==============================] - 1s 77us/step - loss: 2.7274
#
# Epoch 00024: CRPS_score_val improved from 0.01299 to 0.01299, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.7274
#
# Epoch 00025: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 2s 103us/step - loss: 2.7253
#
# Epoch 00026: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# Epoch 27/100
# 18536/18536 [==============================] - 2s 85us/step - loss: 2.7180
#
# Epoch 00027: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# Epoch 28/100
# 18536/18536 [==============================] - 2s 112us/step - loss: 2.7136
#
# Epoch 00028: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# Epoch 29/100
# 18536/18536 [==============================] - 1s 75us/step - loss: 2.7094
#
# Epoch 00029: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 30/100
# 18536/18536 [==============================] - 1s 75us/step - loss: 2.7069
#
# Epoch 00030: CRPS_score_val improved from 0.01292 to 0.01291, saving model to best_model.h5
# Epoch 31/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.7000
#
# Epoch 00031: CRPS_score_val improved from 0.01291 to 0.01291, saving model to best_model.h5
# Epoch 32/100
# 18536/18536 [==============================] - 2s 86us/step - loss: 2.6923
#
# Epoch 00032: CRPS_score_val did not improve from 0.01291
# Epoch 33/100
# 18536/18536 [==============================] - 2s 84us/step - loss: 2.6952
#
# Epoch 00033: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 34/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6859
#
# Epoch 00034: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 35/100
# 18536/18536 [==============================] - 2s 84us/step - loss: 2.6906
#
# Epoch 00035: CRPS_score_val did not improve from 0.01289
# Epoch 36/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.6894
#
# Epoch 00036: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 37/100
# 18536/18536 [==============================] - 1s 77us/step - loss: 2.6808
#
# Epoch 00037: CRPS_score_val improved from 0.01288 to 0.01288, saving model to best_model.h5
# Epoch 38/100
# 18536/18536 [==============================] - 2s 84us/step - loss: 2.6832
#
# Epoch 00038: CRPS_score_val did not improve from 0.01288
# Epoch 39/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6743
#
# Epoch 00039: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 40/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6705
#
# Epoch 00040: CRPS_score_val did not improve from 0.01287
# Epoch 41/100
# 18536/18536 [==============================] - 2s 87us/step - loss: 2.6668
#
# Epoch 00041: CRPS_score_val did not improve from 0.01287
# Epoch 42/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.6697
#
# Epoch 00042: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 43/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6682
#
# Epoch 00043: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 44/100
# 18536/18536 [==============================] - 1s 77us/step - loss: 2.6658
#
# Epoch 00044: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 45/100
# 18536/18536 [==============================] - 1s 76us/step - loss: 2.6616
#
# Epoch 00045: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 46/100
# 18536/18536 [==============================] - 1s 78us/step - loss: 2.6650
#
# Epoch 00046: CRPS_score_val did not improve from 0.01284
# Epoch 47/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6554
#
# Epoch 00047: CRPS_score_val did not improve from 0.01284
# Epoch 48/100
# 18536/18536 [==============================] - 1s 77us/step - loss: 2.6563
#
# Epoch 00048: CRPS_score_val did not improve from 0.01284
# Epoch 49/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6545
#
# Epoch 00049: CRPS_score_val did not improve from 0.01284
# Epoch 50/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6473
#
# Epoch 00050: CRPS_score_val did not improve from 0.01284
# Epoch 51/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 2.6495
#
# Epoch 00051: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 52/100
# 18536/18536 [==============================] - 2s 89us/step - loss: 2.6481
#
# Epoch 00052: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 53/100
# 18536/18536 [==============================] - 2s 93us/step - loss: 2.6425
#
# Epoch 00053: CRPS_score_val did not improve from 0.01282
# Epoch 54/100
# 18536/18536 [==============================] - 1s 75us/step - loss: 2.6417
#
# Epoch 00054: CRPS_score_val did not improve from 0.01282
# Epoch 55/100
# 18536/18536 [==============================] - 1s 75us/step - loss: 2.6435
#
# Epoch 00055: CRPS_score_val did not improve from 0.01282
# Epoch 56/100
# 18536/18536 [==============================] - 1s 74us/step - loss: 2.6369
#
# Epoch 00056: CRPS_score_val did not improve from 0.01282
# Epoch 57/100
# 18536/18536 [==============================] - 1s 76us/step - loss: 2.6333
#
# Epoch 00057: CRPS_score_val did not improve from 0.01282
# Epoch 58/100
# 18536/18536 [==============================] - 1s 74us/step - loss: 2.6347
#
# Epoch 00058: CRPS_score_val did not improve from 0.01282
# Epoch 59/100
# 18536/18536 [==============================] - 1s 74us/step - loss: 2.6250
#
# Epoch 00059: CRPS_score_val did not improve from 0.01282
# Epoch 60/100
# 18536/18536 [==============================] - 1s 73us/step - loss: 2.6254
#
# Epoch 00060: CRPS_score_val did not improve from 0.01282
# Epoch 61/100
# 18536/18536 [==============================] - 1s 72us/step - loss: 2.6277
#
# Epoch 00061: CRPS_score_val did not improve from 0.01282
# Epoch 62/100
# 18536/18536 [==============================] - 1s 72us/step - loss: 2.6305
# Restoring model weights from the end of the best epoch
#
# Epoch 00062: CRPS_score_val did not improve from 0.01282
# Epoch 00062: early stopping
# the 1 fold crps is 0.012822
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 127us/step - loss: 5.6045
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08273, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 5.1337
#
# Epoch 00002: CRPS_score_val improved from 0.08273 to 0.07822, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 4.7347
#
# Epoch 00003: CRPS_score_val improved from 0.07822 to 0.06493, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 4.3310
#
# Epoch 00004: CRPS_score_val improved from 0.06493 to 0.04596, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 3.9390
#
# Epoch 00005: CRPS_score_val improved from 0.04596 to 0.02878, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.5651
#
# Epoch 00006: CRPS_score_val improved from 0.02878 to 0.01973, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 3.2974
#
# Epoch 00007: CRPS_score_val improved from 0.01973 to 0.01580, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.1208
#
# Epoch 00008: CRPS_score_val improved from 0.01580 to 0.01423, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.0127
#
# Epoch 00009: CRPS_score_val improved from 0.01423 to 0.01371, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.9398
#
# Epoch 00010: CRPS_score_val improved from 0.01371 to 0.01347, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.8901
#
# Epoch 00011: CRPS_score_val improved from 0.01347 to 0.01335, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.8603
#
# Epoch 00012: CRPS_score_val improved from 0.01335 to 0.01325, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.8378
#
# Epoch 00013: CRPS_score_val improved from 0.01325 to 0.01322, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.8204
#
# Epoch 00014: CRPS_score_val improved from 0.01322 to 0.01317, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7998
#
# Epoch 00015: CRPS_score_val improved from 0.01317 to 0.01313, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7910
#
# Epoch 00016: CRPS_score_val improved from 0.01313 to 0.01309, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.7829
#
# Epoch 00017: CRPS_score_val improved from 0.01309 to 0.01306, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7691
#
# Epoch 00018: CRPS_score_val improved from 0.01306 to 0.01305, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.7597
#
# Epoch 00019: CRPS_score_val improved from 0.01305 to 0.01301, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 1s 73us/step - loss: 2.7561
#
# Epoch 00020: CRPS_score_val improved from 0.01301 to 0.01299, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 1s 75us/step - loss: 2.7445
#
# Epoch 00021: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 1s 75us/step - loss: 2.7369
#
# Epoch 00022: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.7355
#
# Epoch 00023: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.7301
#
# Epoch 00024: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 2.7208
#
# Epoch 00025: CRPS_score_val improved from 0.01292 to 0.01290, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7273
#
# Epoch 00026: CRPS_score_val did not improve from 0.01290
# Epoch 27/100
# 18537/18537 [==============================] - 2s 109us/step - loss: 2.7208
#
# Epoch 00027: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.7122
#
# Epoch 00028: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7141
#
# Epoch 00029: CRPS_score_val did not improve from 0.01288
# Epoch 30/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7088
#
# Epoch 00030: CRPS_score_val did not improve from 0.01288
# Epoch 31/100
# 18537/18537 [==============================] - 1s 75us/step - loss: 2.7003
#
# Epoch 00031: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.6946
#
# Epoch 00032: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6894
#
# Epoch 00033: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6877
#
# Epoch 00034: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6875
#
# Epoch 00035: CRPS_score_val did not improve from 0.01285
# Epoch 36/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6860
#
# Epoch 00036: CRPS_score_val did not improve from 0.01285
# Epoch 37/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6828
#
# Epoch 00037: CRPS_score_val did not improve from 0.01285
# Epoch 38/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6805
#
# Epoch 00038: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6737
#
# Epoch 00039: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6742
#
# Epoch 00040: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6715
#
# Epoch 00041: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 133us/step - loss: 2.6654
#
# Epoch 00042: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 113us/step - loss: 2.6669
#
# Epoch 00043: CRPS_score_val did not improve from 0.01282
# Epoch 44/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6638
#
# Epoch 00044: CRPS_score_val did not improve from 0.01282
# Epoch 45/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6588
#
# Epoch 00045: CRPS_score_val did not improve from 0.01282
# Epoch 46/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6544
#
# Epoch 00046: CRPS_score_val did not improve from 0.01282
# Epoch 47/100
# 18537/18537 [==============================] - 2s 118us/step - loss: 2.6537
#
# Epoch 00047: CRPS_score_val did not improve from 0.01282
# Epoch 48/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.6555
#
# Epoch 00048: CRPS_score_val did not improve from 0.01282
# Epoch 49/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6470
#
# Epoch 00049: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6489
#
# Epoch 00050: CRPS_score_val did not improve from 0.01282
# Epoch 51/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6467
#
# Epoch 00051: CRPS_score_val did not improve from 0.01282
# Epoch 52/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6440
#
# Epoch 00052: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 3s 145us/step - loss: 2.6416
#
# Epoch 00053: CRPS_score_val did not improve from 0.01281
# Epoch 54/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6388
#
# Epoch 00054: CRPS_score_val did not improve from 0.01281
# Epoch 55/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.6382
#
# Epoch 00055: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6366
#
# Epoch 00056: CRPS_score_val did not improve from 0.01280
# Epoch 57/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6333
#
# Epoch 00057: CRPS_score_val did not improve from 0.01280
# Epoch 58/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6295
#
# Epoch 00058: CRPS_score_val did not improve from 0.01280
# Epoch 59/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6237
#
# Epoch 00059: CRPS_score_val did not improve from 0.01280
# Epoch 60/100
# 18537/18537 [==============================] - 1s 75us/step - loss: 2.6260
#
# Epoch 00060: CRPS_score_val did not improve from 0.01280
# Epoch 61/100
# 18537/18537 [==============================] - 1s 75us/step - loss: 2.6237
#
# Epoch 00061: CRPS_score_val did not improve from 0.01280
# Epoch 62/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6212
#
# Epoch 00062: CRPS_score_val did not improve from 0.01280
# Epoch 63/100
# 18537/18537 [==============================] - 1s 75us/step - loss: 2.6137
#
# Epoch 00063: CRPS_score_val did not improve from 0.01280
# Epoch 64/100
# 18537/18537 [==============================] - 1s 73us/step - loss: 2.6155
#
# Epoch 00064: CRPS_score_val did not improve from 0.01280
# Epoch 65/100
# 18537/18537 [==============================] - 1s 75us/step - loss: 2.6165
# Restoring model weights from the end of the best epoch
#
# Epoch 00065: CRPS_score_val did not improve from 0.01280
# Epoch 00065: early stopping
# the 2 fold crps is 0.012804
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 5.6025
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08264, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 5.1230
#
# Epoch 00002: CRPS_score_val improved from 0.08264 to 0.07848, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 4.7283
#
# Epoch 00003: CRPS_score_val improved from 0.07848 to 0.06506, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 73us/step - loss: 4.3432
#
# Epoch 00004: CRPS_score_val improved from 0.06506 to 0.04504, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 74us/step - loss: 3.9423
#
# Epoch 00005: CRPS_score_val improved from 0.04504 to 0.02871, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 3.5941
#
# Epoch 00006: CRPS_score_val improved from 0.02871 to 0.01955, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 3.3097
#
# Epoch 00007: CRPS_score_val improved from 0.01955 to 0.01587, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 3.1331
#
# Epoch 00008: CRPS_score_val improved from 0.01587 to 0.01436, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 3.0059
#
# Epoch 00009: CRPS_score_val improved from 0.01436 to 0.01362, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.9420
#
# Epoch 00010: CRPS_score_val improved from 0.01362 to 0.01338, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.9011
#
# Epoch 00011: CRPS_score_val improved from 0.01338 to 0.01326, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8685
#
# Epoch 00012: CRPS_score_val improved from 0.01326 to 0.01317, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 3s 136us/step - loss: 2.8437
#
# Epoch 00013: CRPS_score_val improved from 0.01317 to 0.01311, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.8180
#
# Epoch 00014: CRPS_score_val improved from 0.01311 to 0.01307, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.8032
#
# Epoch 00015: CRPS_score_val improved from 0.01307 to 0.01302, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.7960
#
# Epoch 00016: CRPS_score_val improved from 0.01302 to 0.01298, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.7803
#
# Epoch 00017: CRPS_score_val improved from 0.01298 to 0.01295, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7796
#
# Epoch 00018: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7665
#
# Epoch 00019: CRPS_score_val improved from 0.01294 to 0.01292, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.7563
#
# Epoch 00020: CRPS_score_val improved from 0.01292 to 0.01289, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7521
#
# Epoch 00021: CRPS_score_val improved from 0.01289 to 0.01289, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7396
#
# Epoch 00022: CRPS_score_val improved from 0.01289 to 0.01286, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.7373
#
# Epoch 00023: CRPS_score_val improved from 0.01286 to 0.01284, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7355
#
# Epoch 00024: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7237
#
# Epoch 00025: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7187
#
# Epoch 00026: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7172
#
# Epoch 00027: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7161
#
# Epoch 00028: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7085
#
# Epoch 00029: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.7021
#
# Epoch 00030: CRPS_score_val did not improve from 0.01278
# Epoch 31/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7042
#
# Epoch 00031: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6950
#
# Epoch 00032: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6934
#
# Epoch 00033: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6896
#
# Epoch 00034: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6864
#
# Epoch 00035: CRPS_score_val did not improve from 0.01275
# Epoch 36/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6917
#
# Epoch 00036: CRPS_score_val did not improve from 0.01275
# Epoch 37/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6899
#
# Epoch 00037: CRPS_score_val improved from 0.01275 to 0.01275, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6786
#
# Epoch 00038: CRPS_score_val did not improve from 0.01275
# Epoch 39/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6787
#
# Epoch 00039: CRPS_score_val improved from 0.01275 to 0.01275, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.6753
#
# Epoch 00040: CRPS_score_val did not improve from 0.01275
# Epoch 41/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6719
#
# Epoch 00041: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6733
#
# Epoch 00042: CRPS_score_val did not improve from 0.01274
# Epoch 43/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6716
#
# Epoch 00043: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 2.6652
#
# Epoch 00044: CRPS_score_val did not improve from 0.01273
# Epoch 45/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6663
#
# Epoch 00045: CRPS_score_val did not improve from 0.01273
# Epoch 46/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6616
#
# Epoch 00046: CRPS_score_val did not improve from 0.01273
# Epoch 47/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6603
#
# Epoch 00047: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 48/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6564
#
# Epoch 00048: CRPS_score_val did not improve from 0.01272
# Epoch 49/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.6513
#
# Epoch 00049: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 121us/step - loss: 2.6540
#
# Epoch 00050: CRPS_score_val did not improve from 0.01272
# Epoch 51/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.6466
#
# Epoch 00051: CRPS_score_val did not improve from 0.01272
# Epoch 52/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6492
#
# Epoch 00052: CRPS_score_val did not improve from 0.01272
# Epoch 53/100
# 18537/18537 [==============================] - 2s 132us/step - loss: 2.6436
#
# Epoch 00053: CRPS_score_val did not improve from 0.01272
# Epoch 54/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6439
#
# Epoch 00054: CRPS_score_val did not improve from 0.01272
# Epoch 55/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6369
#
# Epoch 00055: CRPS_score_val did not improve from 0.01272
# Epoch 56/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6381
#
# Epoch 00056: CRPS_score_val did not improve from 0.01272
# Epoch 57/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6396
#
# Epoch 00057: CRPS_score_val did not improve from 0.01272
# Epoch 58/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6351
#
# Epoch 00058: CRPS_score_val did not improve from 0.01272
# Epoch 59/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6306
# Restoring model weights from the end of the best epoch
#
# Epoch 00059: CRPS_score_val did not improve from 0.01272
# Epoch 00059: early stopping
# the 3 fold crps is 0.012716
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 125us/step - loss: 5.5828
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08188, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 108us/step - loss: 5.0955
#
# Epoch 00002: CRPS_score_val improved from 0.08188 to 0.07734, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 4.6834
#
# Epoch 00003: CRPS_score_val improved from 0.07734 to 0.06212, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.2657
#
# Epoch 00004: CRPS_score_val improved from 0.06212 to 0.04137, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 3.9058
#
# Epoch 00005: CRPS_score_val improved from 0.04137 to 0.02660, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 3.5673
#
# Epoch 00006: CRPS_score_val improved from 0.02660 to 0.01896, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 3.3179
#
# Epoch 00007: CRPS_score_val improved from 0.01896 to 0.01552, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.1384
#
# Epoch 00008: CRPS_score_val improved from 0.01552 to 0.01408, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 3.0143
#
# Epoch 00009: CRPS_score_val improved from 0.01408 to 0.01353, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.9372
#
# Epoch 00010: CRPS_score_val improved from 0.01353 to 0.01326, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.8934
#
# Epoch 00011: CRPS_score_val improved from 0.01326 to 0.01313, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.8638
#
# Epoch 00012: CRPS_score_val improved from 0.01313 to 0.01309, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.8387
#
# Epoch 00013: CRPS_score_val improved from 0.01309 to 0.01301, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.8124
#
# Epoch 00014: CRPS_score_val improved from 0.01301 to 0.01297, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7985
#
# Epoch 00015: CRPS_score_val improved from 0.01297 to 0.01293, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7844
#
# Epoch 00016: CRPS_score_val improved from 0.01293 to 0.01291, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.7773
#
# Epoch 00017: CRPS_score_val improved from 0.01291 to 0.01289, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 110us/step - loss: 2.7661
#
# Epoch 00018: CRPS_score_val improved from 0.01289 to 0.01285, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7602
#
# Epoch 00019: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7449
#
# Epoch 00020: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 101us/step - loss: 2.7382
#
# Epoch 00021: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.7336
#
# Epoch 00022: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7294
#
# Epoch 00023: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7316
#
# Epoch 00024: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.7254
#
# Epoch 00025: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.7161
#
# Epoch 00026: CRPS_score_val improved from 0.01274 to 0.01274, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7146
#
# Epoch 00027: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7097
#
# Epoch 00028: CRPS_score_val improved from 0.01273 to 0.01271, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.7073
#
# Epoch 00029: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7064
#
# Epoch 00030: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.7043
#
# Epoch 00031: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6995
#
# Epoch 00032: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6954
#
# Epoch 00033: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6887
#
# Epoch 00034: CRPS_score_val did not improve from 0.01268
# Epoch 35/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6924
#
# Epoch 00035: CRPS_score_val did not improve from 0.01268
# Epoch 36/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6871
#
# Epoch 00036: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6807
#
# Epoch 00037: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6794
#
# Epoch 00038: CRPS_score_val improved from 0.01268 to 0.01266, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6702
#
# Epoch 00039: CRPS_score_val did not improve from 0.01266
# Epoch 40/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6729
#
# Epoch 00040: CRPS_score_val did not improve from 0.01266
# Epoch 41/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6701
#
# Epoch 00041: CRPS_score_val did not improve from 0.01266
# Epoch 42/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6737
#
# Epoch 00042: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6685
#
# Epoch 00043: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6683
#
# Epoch 00044: CRPS_score_val improved from 0.01265 to 0.01265, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6637
#
# Epoch 00045: CRPS_score_val did not improve from 0.01265
# Epoch 46/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6497
#
# Epoch 00046: CRPS_score_val did not improve from 0.01265
# Epoch 47/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6619
#
# Epoch 00047: CRPS_score_val did not improve from 0.01265
# Epoch 48/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6543
#
# Epoch 00048: CRPS_score_val did not improve from 0.01265
# Epoch 49/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6532
#
# Epoch 00049: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6519
#
# Epoch 00050: CRPS_score_val did not improve from 0.01264
# Epoch 51/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6517
#
# Epoch 00051: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6484
#
# Epoch 00052: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6432
#
# Epoch 00053: CRPS_score_val improved from 0.01263 to 0.01263, saving model to best_model.h5
# Epoch 54/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6377
#
# Epoch 00054: CRPS_score_val did not improve from 0.01263
# Epoch 55/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6426
#
# Epoch 00055: CRPS_score_val did not improve from 0.01263
# Epoch 56/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6377
#
# Epoch 00056: CRPS_score_val did not improve from 0.01263
# Epoch 57/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6324
#
# Epoch 00057: CRPS_score_val did not improve from 0.01263
# Epoch 58/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6291
#
# Epoch 00058: CRPS_score_val did not improve from 0.01263
# Epoch 59/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6279
#
# Epoch 00059: CRPS_score_val did not improve from 0.01263
# Epoch 60/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6265
#
# Epoch 00060: CRPS_score_val did not improve from 0.01263
# Epoch 61/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.6213
#
# Epoch 00061: CRPS_score_val did not improve from 0.01263
# Epoch 62/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6184
#
# Epoch 00062: CRPS_score_val did not improve from 0.01263
# Epoch 63/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6186
# Restoring model weights from the end of the best epoch
#
# Epoch 00063: CRPS_score_val did not improve from 0.01263
# Epoch 00063: early stopping
# the 4 fold crps is 0.012625
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 127us/step - loss: 5.5886
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08271, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 5.1320
#
# Epoch 00002: CRPS_score_val improved from 0.08271 to 0.07801, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 4.7312
#
# Epoch 00003: CRPS_score_val improved from 0.07801 to 0.06526, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 4.3369
#
# Epoch 00004: CRPS_score_val improved from 0.06526 to 0.04433, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 3.9566
#
# Epoch 00005: CRPS_score_val improved from 0.04433 to 0.02724, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 3.5958
#
# Epoch 00006: CRPS_score_val improved from 0.02724 to 0.01943, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 3.3251
#
# Epoch 00007: CRPS_score_val improved from 0.01943 to 0.01595, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 3.1280
#
# Epoch 00008: CRPS_score_val improved from 0.01595 to 0.01450, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 125us/step - loss: 3.0116
#
# Epoch 00009: CRPS_score_val improved from 0.01450 to 0.01402, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.9407
#
# Epoch 00010: CRPS_score_val improved from 0.01402 to 0.01380, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.9024
#
# Epoch 00011: CRPS_score_val improved from 0.01380 to 0.01369, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.8649
#
# Epoch 00012: CRPS_score_val improved from 0.01369 to 0.01362, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.8390
#
# Epoch 00013: CRPS_score_val improved from 0.01362 to 0.01354, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.8178
#
# Epoch 00014: CRPS_score_val improved from 0.01354 to 0.01348, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.8080
#
# Epoch 00015: CRPS_score_val improved from 0.01348 to 0.01343, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7875
#
# Epoch 00016: CRPS_score_val improved from 0.01343 to 0.01341, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.7792
#
# Epoch 00017: CRPS_score_val improved from 0.01341 to 0.01337, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.7718
#
# Epoch 00018: CRPS_score_val improved from 0.01337 to 0.01333, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.7584
#
# Epoch 00019: CRPS_score_val improved from 0.01333 to 0.01331, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.7548
#
# Epoch 00020: CRPS_score_val improved from 0.01331 to 0.01331, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7459
#
# Epoch 00021: CRPS_score_val improved from 0.01331 to 0.01326, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7396
#
# Epoch 00022: CRPS_score_val improved from 0.01326 to 0.01325, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7332
#
# Epoch 00023: CRPS_score_val improved from 0.01325 to 0.01323, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.7282
#
# Epoch 00024: CRPS_score_val did not improve from 0.01323
# Epoch 25/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7208
#
# Epoch 00025: CRPS_score_val improved from 0.01323 to 0.01321, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.7202
#
# Epoch 00026: CRPS_score_val improved from 0.01321 to 0.01320, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7167
#
# Epoch 00027: CRPS_score_val improved from 0.01320 to 0.01319, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.7108
#
# Epoch 00028: CRPS_score_val improved from 0.01319 to 0.01317, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 3s 137us/step - loss: 2.7101
#
# Epoch 00029: CRPS_score_val did not improve from 0.01317
# Epoch 30/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7037
#
# ...
# Epoch 41/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.6679
#
# Epoch 00041: CRPS_score_val improved from 0.01341 to 0.01341, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6644
#
# Epoch 00042: CRPS_score_val did not improve from 0.01341
# Epoch 43/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6607
#
# Epoch 00043: CRPS_score_val improved from 0.01341 to 0.01341, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6591
#
# Epoch 00044: CRPS_score_val did not improve from 0.01341
# Epoch 45/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6621
#
# Epoch 00045: CRPS_score_val improved from 0.01341 to 0.01339, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6568
#
# Epoch 00046: CRPS_score_val did not improve from 0.01339
# Epoch 47/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6538
#
# Epoch 00047: CRPS_score_val did not improve from 0.01339
# Epoch 48/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6526
#
# Epoch 00048: CRPS_score_val did not improve from 0.01339
# Epoch 49/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6541
#
# Epoch 00049: CRPS_score_val improved from 0.01339 to 0.01338, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6451
#
# Epoch 00050: CRPS_score_val improved from 0.01338 to 0.01338, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6449
#
# Epoch 00051: CRPS_score_val improved from 0.01338 to 0.01338, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6439
#
# Epoch 00052: CRPS_score_val did not improve from 0.01338
# Epoch 53/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6432
#
# Epoch 00053: CRPS_score_val improved from 0.01338 to 0.01336, saving model to best_model.h5
# Epoch 54/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6469
#
# Epoch 00054: CRPS_score_val did not improve from 0.01336
# Epoch 55/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6357
#
# Epoch 00055: CRPS_score_val did not improve from 0.01336
# Epoch 56/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6389
#
# Epoch 00056: CRPS_score_val improved from 0.01336 to 0.01336, saving model to best_model.h5
# Epoch 57/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6355
#
# Epoch 00057: CRPS_score_val did not improve from 0.01336
# Epoch 58/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6310
#
# Epoch 00058: CRPS_score_val did not improve from 0.01336
# Epoch 59/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6245
#
# Epoch 00059: CRPS_score_val did not improve from 0.01336
# Epoch 60/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6257
#
# Epoch 00060: CRPS_score_val did not improve from 0.01336
# Epoch 61/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6268
#
# Epoch 00061: CRPS_score_val did not improve from 0.01336
# Epoch 62/100
# 18537/18537 [==============================] - 2s 114us/step - loss: 2.6233
#
# Epoch 00062: CRPS_score_val did not improve from 0.01336
# Epoch 63/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6184
#
# Epoch 00063: CRPS_score_val did not improve from 0.01336
# Epoch 64/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6231
#
# Epoch 00064: CRPS_score_val did not improve from 0.01336
# Epoch 65/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6117
#
# Epoch 00065: CRPS_score_val did not improve from 0.01336
# Epoch 66/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6078
# Restoring model weights from the end of the best epoch
#
# Epoch 00066: CRPS_score_val did not improve from 0.01336
# Epoch 00066: early stopping
# the 4 fold crps is 0.013356
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 5.6006
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08242, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 5.1434
#
# Epoch 00002: CRPS_score_val improved from 0.08242 to 0.07804, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 107us/step - loss: 4.7178
#
# Epoch 00003: CRPS_score_val improved from 0.07804 to 0.06474, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 121us/step - loss: 4.2921
#
# Epoch 00004: CRPS_score_val improved from 0.06474 to 0.04378, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 3.9073
#
# Epoch 00005: CRPS_score_val improved from 0.04378 to 0.02740, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.5839
#
# Epoch 00006: CRPS_score_val improved from 0.02740 to 0.01930, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.3065
#
# Epoch 00007: CRPS_score_val improved from 0.01930 to 0.01550, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 3.1088
#
# Epoch 00008: CRPS_score_val improved from 0.01550 to 0.01413, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.9937
#
# Epoch 00009: CRPS_score_val improved from 0.01413 to 0.01352, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.9331
#
# Epoch 00010: CRPS_score_val improved from 0.01352 to 0.01325, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 116us/step - loss: 2.8935
#
# Epoch 00011: CRPS_score_val improved from 0.01325 to 0.01316, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.8602
#
# Epoch 00012: CRPS_score_val improved from 0.01316 to 0.01310, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.8410
#
# Epoch 00013: CRPS_score_val improved from 0.01310 to 0.01305, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.8075
#
# Epoch 00014: CRPS_score_val improved from 0.01305 to 0.01302, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7958
#
# Epoch 00015: CRPS_score_val improved from 0.01302 to 0.01298, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7831
#
# Epoch 00016: CRPS_score_val improved from 0.01298 to 0.01296, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7801
#
# Epoch 00017: CRPS_score_val improved from 0.01296 to 0.01293, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7659
#
# Epoch 00018: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7593
#
# Epoch 00019: CRPS_score_val improved from 0.01292 to 0.01287, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.7534
#
# Epoch 00020: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7413
#
# Epoch 00021: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7364
#
# Epoch 00022: CRPS_score_val improved from 0.01286 to 0.01284, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.7368
#
# Epoch 00023: CRPS_score_val improved from 0.01284 to 0.01282, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7323
#
# Epoch 00024: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7187
#
# Epoch 00025: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.7160
#
# Epoch 00026: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.7142
#
# Epoch 00027: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7101
#
# Epoch 00028: CRPS_score_val did not improve from 0.01276
# Epoch 29/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.7053
#
# Epoch 00029: CRPS_score_val improved from 0.01276 to 0.01274, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7030
#
# Epoch 00030: CRPS_score_val did not improve from 0.01274
# Epoch 31/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6975
#
# Epoch 00031: CRPS_score_val improved from 0.01274 to 0.01274, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6943
#
# Epoch 00032: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6892
#
# Epoch 00033: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6926
#
# Epoch 00034: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6880
#
# Epoch 00035: CRPS_score_val did not improve from 0.01272
# Epoch 36/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.6826
#
# Epoch 00036: CRPS_score_val did not improve from 0.01272
# Epoch 37/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.6868
#
# Epoch 00037: CRPS_score_val did not improve from 0.01272
# Epoch 38/100
# 18537/18537 [==============================] - 1s 76us/step - loss: 2.6802
#
# Epoch 00038: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6795
#
# Epoch 00039: CRPS_score_val improved from 0.01272 to 0.01270, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 2.6747
#
# Epoch 00040: CRPS_score_val did not improve from 0.01270
# Epoch 41/100
# 18537/18537 [==============================] - 1s 77us/step - loss: 2.6731
#
# Epoch 00041: CRPS_score_val did not improve from 0.01270
# Epoch 42/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6693
#
# Epoch 00042: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.6642
#
# Epoch 00043: CRPS_score_val did not improve from 0.01269
# Epoch 44/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6652
#
# Epoch 00044: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6631
#
# Epoch 00045: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 116us/step - loss: 2.6566
#
# Epoch 00046: CRPS_score_val did not improve from 0.01268
# Epoch 47/100
# 18537/18537 [==============================] - 2s 129us/step - loss: 2.6544
#
# Epoch 00047: CRPS_score_val did not improve from 0.01268
# Epoch 48/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6566
#
# Epoch 00048: CRPS_score_val did not improve from 0.01268
# Epoch 49/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6526
#
# Epoch 00049: CRPS_score_val did not improve from 0.01268
# Epoch 50/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6471
#
# Epoch 00050: CRPS_score_val did not improve from 0.01268
# Epoch 51/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6483
#
# Epoch 00051: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6442
#
# Epoch 00052: CRPS_score_val did not improve from 0.01268
# Epoch 53/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6404
#
# Epoch 00053: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 54/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6376
#
# Epoch 00054: CRPS_score_val did not improve from 0.01268
# Epoch 55/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6400
#
# Epoch 00055: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 2s 88us/step - loss: 2.6343
#
# Epoch 00056: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 57/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6325: 0s - loss: 2.6
#
# Epoch 00057: CRPS_score_val did not improve from 0.01266
# Epoch 58/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6325
#
# Epoch 00058: CRPS_score_val did not improve from 0.01266
# Epoch 59/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6282
#
# Epoch 00059: CRPS_score_val improved from 0.01266 to 0.01264, saving model to best_model.h5
# Epoch 60/100
# 18537/18537 [==============================] - 2s 87us/step - loss: 2.6212
#
# Epoch 00060: CRPS_score_val did not improve from 0.01264
# Epoch 61/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.6229
#
# Epoch 00061: CRPS_score_val did not improve from 0.01264
# Epoch 62/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6257
#
# Epoch 00062: CRPS_score_val did not improve from 0.01264
# Epoch 63/100
# 18537/18537 [==============================] - 2s 89us/step - loss: 2.6220
#
# Epoch 00063: CRPS_score_val did not improve from 0.01264
# Epoch 64/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6193
#
# Epoch 00064: CRPS_score_val did not improve from 0.01264
# Epoch 65/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6165
#
# Epoch 00065: CRPS_score_val did not improve from 0.01264
# Epoch 66/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6135
#
# Epoch 00066: CRPS_score_val did not improve from 0.01264
# Epoch 67/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6047
#
# Epoch 00067: CRPS_score_val did not improve from 0.01264
# Epoch 68/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6054
#
# Epoch 00068: CRPS_score_val did not improve from 0.01264
# Epoch 69/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6090
# Restoring model weights from the end of the best epoch
#
# Epoch 00069: CRPS_score_val did not improve from 0.01264
# Epoch 00069: early stopping
# the 5 fold crps is 0.012639
# mean crps is 0.012799

# %%
print("mean crps is %f"%np.mean(crps_csv))
# Out:
# mean crps is 0.012799
